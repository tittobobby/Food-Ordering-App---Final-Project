# %%
import json
import re

class Restuarent:
    def __init__(self):
        self.foods = {}
        self.food_id = len(self.foods)+1
        self.details = {}
        self.admin_details = {}
        self.admin_info_id = len(self.admin_details) + 1
        self.personal_info_id = len(self.details)+1

 # admin functions       
        
    def food_items(self):
        self.name = input("Enter Food name : ")
        self.quantity = input("Enter Food quantity : ")
        self.price = input("Enter Food price : $ ")
        self.discount = input("Enter Food discount : $ ")
        self.stock = input("Enter Food stock : Kg ")
        self.item = {"name" : self.name, "quantity" : self.quantity, "price" : self.price, "discount" : self.discount, "stock" : self.stock}
        self.food_id = len(self.foods) + 1
        self.foods[self.food_id] = self.item
        print("\nItem added successfully")
        with open("food_items.json", "w") as f:
            json.dump(self.foods,f)
            
    def admin_registration(self):
        self.full_name = input("Enter Full name : ")
        while True:
                phone_number = input("Enter Your Phone Number : ")
                if phone_number.isnumeric() == True:
                    if len(phone_number) == 10:
                        self.phone_number = phone_number
                        break
                    else:
                        print("Invalid Phone Number\n")
                else:
                    print("Invalid Phone Number\n")
        while True:
                regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
                email = input("Enter Your Email Address : ")
                if (re.fullmatch(regex, email)):
                    self.email = email
                    break
                else:
                    print("Invalid Email")
        self.address = input("Enter the full Address : ")
        while True:
                print("Enter password must Contain min. 8 characters\n")
                password = input("Enter Your Password Here : ")
                if len(password) >= 8:
                    self.password = password
                    break
                else:
                    print("Please Enter Minimum 8 Characters\n")
        self.admin_info= {"username" : self.full_name, "phone_number" : self.phone_number, "email" : self.email, "address" : self.address, "password" : self.password}        
        self.admin_info_id = len(self.admin_details) + 1
        self.admin_details[self.admin_info_id] = self.admin_info
        print(self.admin_info)
        print("\nCONGRATULATIONS !! Your account is successfully created")
        with open("admin_details.json", "w") as f:
            json.dump(self.admin_details,f)
            
    def admin_login(self, email, password):
        if len(self.admin_info) > 0:
            if self.admin_info["email"] == email and self.admin_info["password"] == password:
                print("\n!!!!!Login successfully!!!!!")
                print(f"\nWelcome {self.admin_info['username']}")
                return True
            else:
                print("Check email and password again\n")
        else:
            print("This Email Is Not Registerd With Us Please Register First")
        
    def remove_food_items(self):
        del self.foods[int(input("Enter the food_id you want to delete : "))]
        print("Remaining Food items are : ",self.foods)
        with open("food_items.json", "w") as f:
            json.dump(self.foods,f)  
        print("Remaining Food items are : ",self.foods)
    def edit_food_items(self):
        f_id = int(input("Enter food_id which you want to edit : "))
        for i in self.foods[f_id]:
            self.foods[f_id][i] = input(f"Enter the updated {i} : ")
        print(self.foods)
        with open("food_items.json", "w") as f:
            json.dump(self.foods,f)
        print("Food items are edited successfully")
        
    def view_food_items(self):
        if len(self.foods)!=0:
            print("List of all Food items")
            for i in self.foods:
                print("\n*************************\nFood_id : ",i,"\n*************************")
                for j in self.foods[i]:
                    print(j,":",self.foods[i][j])
                print("\n*************************")
        else:
            print("Nothing To Show Here\n")

  #user functions          
        
    def user_profile(self):
        self.full_name = input("Enter Full name : ")
        while True:
                phone_number = input("Enter Your Phone Number : ")
                if phone_number.isnumeric() == True:
                    if len(phone_number) == 10:
                        self.phone_number = phone_number
                        break
                    else:
                        print("Invalid Phone Number\n")
                else:
                    print("Invalid Phone Number\n")
        while True:
                regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
                email = input("Enter Your Email Address : ")
                if (re.fullmatch(regex, email)):
                    self.email = email
                    break
                else:
                    print("Invalid Email")
        self.address = input("Enter the full Address : ")
        while True:
                print("Enter password must Contain min. 8 characters\n")
                password = input("Enter Your Password Here : ")
                if len(password) >= 8:
                    self.password = password
                    break
                else:
                    print("Please Entre Minimum 8 Characters\n")
        self.personal_info = {"username" : self.full_name, "phone_number" : self.phone_number, "email" : self.email, "address" : self.address, "password" : self.password}        
        self.personal_info_id = len(self.details) + 1
        self.details[self.personal_info_id] = self.personal_info
        print(self.details)
        print("\nCONGRATULATIONS !! Your account is successfully created")
        with open("personal_details.json", "w") as f:
            json.dump(self.details,f)
    
    def user_place_order(self):
        print("List Of Items\n1. Tandoori Chicken (4 pieces) [INR 240]\n2. Vegan Burger (1 Piece) [INR 320]\n3. Truffle Cake (500gm) [INR 900]\n\nNOTE : Type '1' if you want to select Tandoori Chicken (4 pieces) [INR 240] and so on..\nType '4' if you want to skip the specific item")
        order_list = ["Tandoori Chicken (4 pieces) [INR 240]","Vegan Burger (1 Piece) [INR 320]","Truffle Cake (500gm) [INR 900]"]
        lst = []
        print("Select the items you wanted to order : ")
        x, y, z = [int(x) for x in input("Please use all 3 options\n(use space after each letter)\nEnter the item_number you want to order : ").split()]
        if x == 1 and y == 4 and z == 4:
            ele = order_list[0]
            lst.append(ele)
        elif y == 2 and x == 4 and z==4:
            ele = order_list[1]
            lst.append(ele)
        elif z == 3 and x==4 and y == 4:
            ele = order_list[2]
            lst.append(ele)
        elif x == 1 and y == 2 and z == 4:
            for i in range(0,2):
                ele = order_list[i]
                lst.append(ele)
        elif x == 1 and y == 4 and z == 3:
            for i in range(0,3,2):
                ele = order_list[i]
                lst.append(ele)
        elif x == 4 and y == 2 and z == 3:
            for i in range(1,3):
                ele = order_list[i]
                lst.append(ele)
        elif x == 1 and y ==2 and z ==3:
            for i in range(0,3):
                ele = order_list[i]
                lst.append(ele)
        else:
            print("Wrong data !! Enter the correct data")
    
        print("\nYou have successfully placed the order !!") 
        print(f"Your order is : ")
        print("******************************************************************************************")
        print(lst)
        print("******************************************************************************************")
        with open("user_order.json", "w") as f:
            json.dump(lst,f)

    def user_order_history(self):
        print("\nPrevious order is shown below : ")
        with open("user_order.json", "r") as f:
            x = json.load(f)
            y = json.dumps(x)
            print("******************************************************************************************")
            print(y)
            print("******************************************************************************************")

    
    def user_login(self, email, password):
        
        if len(self.personal_info) > 0:
            if self.personal_info["email"] == email and self.personal_info["password"] == password:
                print("\n!!!!!Login successfully!!!!!")
                print(f"\nWelcome {self.personal_info['username']}")
                return True
            else:
                print("Check email and password again\n")
        else:
            print("This Email Is Not Registerd With Us Please Register First")
            

    
    def update_user_profile(self, password):
        if self.personal_info["password"] == password:
            while True:
                print("\n 1.Update Your Name\n 2.Update Your Phone Number\n 3.Update Your Email\n 4.Update Your Address\n 5.Update Your Password\n 6.Exit")
                update_choice = input("Enter Your Choice : ")
                if update_choice == "1":
                    print(f"Your Current Profile Name is : {self.personal_info['username']}")
                    newname = input("Entre new Name \n")
                    self.personal_info["username"] = newname
                    print(" Name Updated successfully !!")
                elif update_choice == "2":
                    print(f"Your Current Phone Number is : {self.personal_info['phone_number']}")
                    while True:
                        newnum = input("Entre new Number : ")
                        if newnum.isnumeric() == True:
                            if len(newnum) == 10:
                                self.personal_info["phone_number"] = newnum
                                print("Phone Number Updated")
                                break
                            else:
                                print("Invalid Phone Number")
                        else:
                            print("Invalid Phone Number")
                elif update_choice == '3':
                    print(f"Your Current Email is : {self.personal_info['email']}")
                    while True:
                        regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
                        newemail = input("Enter Your Email Address : ")
                        if (re.fullmatch(regex, newemail)):
                            self.personal_info['email'] = newemail
                            print("Email Address Updated Successfully !!")
                            break
                        else:
                            print("Invalid Email")
                elif update_choice == '4':
                    print(f"Your Current Address is : {self.personal_info['address']}")
                    newadd = input("Enter new Address : ")
                    self.personal_info["address"] = newadd
                    print("Address Updated Successfully !!")
                elif update_choice == '5':
                    print("Password must Contain min. 8 characters")
                    while True:
                        newpass = input("Enter new Password : ")
                        if len(newpass) >= 8:
                            self.personal_info["password"] = newpass
                            print("Password Updated Successfully !!")
                            break
                        else:
                            print("Please Entre Minimum 8 Characters")
                elif update_choice == '6':
                    break
                else:
                    print("Please provide a valid Input")
        else:
            print("Wrong Password !! Enter a Valid Password To continue")
                
        

def Driver_code():
    #driver code to run main function
    try:
        r = Restuarent()
        while True:
            print(f'Welcome to my Restuarent\n')
            print("Please Enter Your Selection from Below Options")
            print('\n1. ADMIN')
            print('2. USER')
            print('3. CLOSE')
            Dinput = input('Enter Your Selection : \n')
            if Dinput == '1':
                while True:
                    print('\n1. ADMIN REGISTER')
                    print('2. ADMIN LOGIN')
                    print('3. BACK')
                    Dinput2 = input('Enter Your Selection : \n')
                    if Dinput2 == '1':
                        r.admin_registration()
                    elif Dinput2 == '2':
                        email = input("Enter your registered Admin's Email Address : \n")
                        password = input('Enter Admin Password : \n')
                        if r.admin_login(email, password):
                            while True:
                                print('\n1. Add new food item')
                                print('2. Edit food item')
                                print('3. View food item')
                                print('4. Delete food item')
                                print('5. Back')
                                X = input('\nEnter Your Selection : ')
                                if X == '1':
                                    r.food_items()
                                elif X == '2':
                                    r.edit_food_items()
                                elif X == '3':
                                    r.view_food_items()
                                elif X == '4':
                                    r.remove_food_items()
                                elif X == '5':
                                    break
                                else:
                                    print('Invalid option')
                        else:
                            print("Invalid Email Address or Password")
                    elif Dinput2 == '3':
                        break
                    else:
                        print("INVALID OPTION")
            elif Dinput == '2':
                while True:
                    print('\n1. User Registration')
                    print('2. User Login')
                    print('3. Exit')
                    uinput = input("\nEnter Your Selection : ")
                    if uinput == '1':
                        r.user_profile()
                    elif uinput == '2':
                        uemail = input("\nEnter Your Registerd Email Here : ")
                        upassword = input("Enter Your Password : ")
                        if r.user_login(uemail, upassword):
                            while True:
                                print('\n1. Place Order')
                                print('2. Show Order History')
                                print('3. Update Profile Details')
                                print('4. Back')
                                uinput2 = input("\nEnter Your Choice : ")
                                if uinput2 == '1':
                                    r.user_place_order()
                                elif uinput2 == '2':
                                    r.user_order_history()
                                elif uinput2 == '3':
                                    password = input("Enter the password : ")
                                    r.update_user_profile(password)
                                elif uinput2 == "4":
                                    break
                                else:
                                    print("Please give a valid Input")
                        else:
                            print("Invalid Email Address Or Password")
                    elif uinput == '3':
                        break
                    else:
                        print("Entre Valid Input")
            elif Dinput == '3':
                break
            else:
                print('Please enter again')
    except Exception as e:
            print('!! Something Went Wrong We will Work on it !!\n')

if __name__ == "__main__":
    Driver_code()
# Out:
# Welcome to my Restuarent
#
# Please Enter Your Selection from Below Options
#
# 1. ADMIN
# 2. USER
# 3. CLOSE
